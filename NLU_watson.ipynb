# %%
# !pip install --upgrade "watson-developer-cloud>=2.5.1"
# Out:
# ...
#     100% |████████████████████████████████| 256kB 7.6MB/s
# ...
#     100% |████████████████████████████████| 204kB 30.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/10/f4/7d/334121aa42043688072ce8a5c12179fd017ec0d30e8c95e009
# Successfully built watson-developer-cloud
# ...

# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import EntitiesOptions,KeywordsOptions,Features, CategoriesOptions

natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    iam_apikey='ENTER YOUR API KEY HERE',
    url='https://gateway-lon.watsonplatform.net/natural-language-understanding/api'
)

response = natural_language_understanding.analyze(
    url='http://www.textfiles.com/stories/100west.txt',
    #text='Bruce Banner is the Hulk and Bruce Wayne is BATMAN! '
    #'Superman fears not Banner, but Wayne.',
    features=Features(entities=EntitiesOptions(),
                      keywords=KeywordsOptions())).get_result()
    #features=Features(categories=CategoriesOptions(limit=3))).get_result()

#json.dumps(response,outfile.json)  
print(json.dumps(response, indent=2))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: NaturalLanguageUnderstandingV1 is a deprecated function. watson-developer-cloud moved to ibm-watson
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 20817,
#     "features": 2
#   },
#   "retrieved_url": "http://www.textfiles.com/stories/100west.txt",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "homes of many city dwellers",
#       "relevance": 0.54908,
#       "count": 1
#     },
#     {
#       "text": "rigors of life",
#       "relevance": 0.547896,
#       "count": 1
#     },
#     {
#       "text": "southern lakes",
#       "relevance": 0.547863,
#       "count": 1
#     },
#     {
#       "text": "presents problems",
#       "relevance": 0.545389,
#       "count": 1
#     },
#     {
#       "text": "charter aircraft",
#       "relevance": 0.544014,
#       "count": 1
#     },
#     {
#       "text": "murderous hordes of black flies",
# ...

# %%
# !pip install google_images_download
# Out:
# ...
#     100% |████████████████████████████████| 911kB 8.2MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d2/23/84/3cec6d566b88bef64ad727a7e805f6544b8af4a8f121f9691c
# Successfully built google-images-download
# ...

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()
arguments={"keywords":"Polar bears,baloons,Beaches","limit":4,"print_urls":True}
absolute_image_paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Polar bears
# Evaluating...
# Starting Download...
# Image URL: https://polarbearsinternational.org/media/3315/00473-54115.jpg
# Completed Image ====> 1. 00473-54115.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Polar_Bear_-_Alaska_%28cropped%29.jpg/220px-Polar_Bear_-_Alaska_%28cropped%29.jpg
# Completed Image ====> 2. 220px-polar_bear_-_alaska_%28cropped%29.jpg
# Image URL: https://www.nwf.org/-/media/NEW-WEBSITE/Shared-Folder/Wildlife/Mammals/mammal_polar_bear_cubs_fighting_alaska_michael_henry_600x300.ashx
# Completed Image ====> 3. mammal_polar_bear_cubs_fighting_alaska_michael_henry_600x300.ash
# Image URL: https://www.motherjones.com/wp-content/uploads/2018/12/20181211-polar-bears.jpg?w=990
# Completed Image ====> 4. 20181211-polar-bears.jpg
# Image URL: https://polarbearsinternational.org/media/3075/ct_110915-23.jpg
# Completed Image ====> 5. ct_110915-23.jpg
# ...

# %%
from IPython.display import Image
Image('downloads/Beaches/11. beach.jpg')

# %%
# !cd downloads
